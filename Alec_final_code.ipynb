# %%
#reading in data
import pandas as pd
pd.set_option('display.max_colwidth', None)
df = pd.read_csv(r'/content/drive/MyDrive/dataframe.csv')

# %%
#selecting columns
sent_ger = pd.read_csv(r'/content/drive/MyDrive/dataframe.csv', usecols = ['sentence', 'gerund_type'])
sent_ger_reldep = pd.read_csv(r'/content/drive/MyDrive/dataframe.csv', usecols = ['sentence', 'gerund_type','relevant_dependencies'])
dependencies = sent_ger = pd.read_csv(r'/content/drive/MyDrive/dataframe.csv', usecols = ['dependencies'])

# %%
#filter by gerund type
values=["vp-of"]
vping = sent_ger_reldep[sent_ger_reldep["gerund_type"].isin(values)]
values1=["ing-of"]
ingof = sent_ger_reldep[sent_ger_reldep["gerund_type"].isin(values1)]
values2=["poss-ing"]
possing = sent_ger_reldep[sent_ger_reldep["gerund_type"].isin(values2)]
values3=["acc-ing"]
accing = sent_ger_reldep[sent_ger_reldep["gerund_type"].isin(values3)]
values4=["det-ing"]
deting = sent_ger_reldep[sent_ger_reldep["gerund_type"].isin(values4)]
values5=["poss-ing-of"]
possingof = sent_ger_reldep[sent_ger_reldep["gerund_type"].isin(values5)]

# %%
#1. before
before_before = sent_ger_reldep[sent_ger_reldep['sentence'].str.contains('before \w+ing')]
before_after = sent_ger_reldep[sent_ger_reldep['sentence'].str.contains('\w+ing before')]

before_dep = sent_ger_reldep[sent_ger_reldep['relevant_dependencies'].str.contains('\((before)-\d+, \w+ing-\d+\)', na=False)]
before_vping = before_dep[before_dep['gerund_type'].str.contains('vp-ing')]
before_accing = before_dep[before_dep['gerund_type'].str.contains('acc-ing')]
before_ingof = before_dep[before_dep['gerund_type'].str.contains('ing-of')]
before_possing = before_dep[before_dep['gerund_type'].str.contains('poss-ing')]
before_deting = before_dep[before_dep['gerund_type'].str.contains('det-ing')]
before_possingof = before_dep[before_dep['gerund_type'].str.contains('poss-ing-of')]

ger_after = before_after[before_after['gerund_type'].str.contains('poss-ing-of')]
ger_after
# Out:
# <ipython-input-35-648489a6969b>:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   before_dep = sent_ger_reldep[sent_ger_reldep['relevant_dependencies'].str.contains('\((before)-\d+, \w+ing-\d+\)', na=False)]
# Empty DataFrame
# Columns: [gerund_type, relevant_dependencies, sentence]
# Index: []

# %%
#2. since
since_before = sent_ger_reldep[sent_ger_reldep['sentence'].str.contains('since \w+ing')]
since_after = sent_ger_reldep[sent_ger_reldep['sentence'].str.contains('\w+ing since')]

since_dep = sent_ger_reldep[sent_ger_reldep['relevant_dependencies'].str.contains('\((since)-\d+, \w+ing-\d+\)', na=False)]
since_vping = since_dep[since_dep['gerund_type'].str.contains('vp-ing')]
since_accing = since_dep[since_dep['gerund_type'].str.contains('acc-ing')]
since_ingof = since_dep[since_dep['gerund_type'].str.contains('ing-of')]
since_possing = since_dep[since_dep['gerund_type'].str.contains('poss-ing')]
since_deting = since_dep[since_dep['gerund_type'].str.contains('det-ing')]
since_possingof = since_dep[since_dep['gerund_type'].str.contains('poss-ing-of')]
# Out:
# <ipython-input-55-aee1b36f75a7>:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   since_dep = sent_ger_reldep[sent_ger_reldep['relevant_dependencies'].str.contains('\((since)-\d+, \w+ing-\d+\)', na=False)]

# %%
#3. while
while_before = sent_ger_reldep[sent_ger_reldep['sentence'].str.contains('while \w+ing')]
while_after = sent_ger_reldep[sent_ger_reldep['sentence'].str.contains('\w+ing while')]

while_dep = sent_ger_reldep[sent_ger_reldep['relevant_dependencies'].str.contains('\((while)-\d+, \w+ing-\d+\)', na=False)]
while_vping = while_dep[while_dep['gerund_type'].str.contains('vp-ing')]
while_accing = while_dep[while_dep['gerund_type'].str.contains('acc-ing')]
while_ingof = while_dep[while_dep['gerund_type'].str.contains('ing-of')]
while_possing = while_dep[while_dep['gerund_type'].str.contains('poss-ing')]
while_deting = while_dep[while_dep['gerund_type'].str.contains('det-ing')]
while_possingof = while_dep[while_dep['gerund_type'].str.contains('poss-ing-of')]
# Out:
# <ipython-input-67-65ed803dd621>:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   while_dep = sent_ger_reldep[sent_ger_reldep['relevant_dependencies'].str.contains('\((while)-\d+, \w+ing-\d+\)', na=False)]

# %%
#4. with
with_before = sent_ger_reldep[sent_ger_reldep['sentence'].str.contains('with \w+ing')]
with_after = sent_ger_reldep[sent_ger_reldep['sentence'].str.contains('\w+ing with')]

with_dep = sent_ger_reldep[sent_ger_reldep['relevant_dependencies'].str.contains('\((with)-\d+, \w+ing-\d+\)', na=False)]
with_vping = with_dep[with_dep['gerund_type'].str.contains('vp-ing')]
with_accing = with_dep[with_dep['gerund_type'].str.contains('acc-ing')]
with_ingof = with_dep[with_dep['gerund_type'].str.contains('ing-of')]
with_possing = with_dep[with_dep['gerund_type'].str.contains('poss-ing')]
with_deting = with_dep[with_dep['gerund_type'].str.contains('det-ing')]
with_possingof = with_dep[with_dep['gerund_type'].str.contains('poss-ing-of')]
# Out:
# <ipython-input-84-4e22d89984ed>:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   with_dep = sent_ger_reldep[sent_ger_reldep['relevant_dependencies'].str.contains('\((with)-\d+, \w+ing-\d+\)', na=False)]
#       gerund_type  \
# 856       det-ing
# 2032      det-ing
# 2321      det-ing
# 3439      det-ing
# 3636      det-ing
# 3644      det-ing
# 7293      det-ing
# 7936      det-ing
# 8986      det-ing
# 9097      det-ing
# 10915     det-ing
# 10958     det-ing
# 11110     det-ing
# 15972     det-ing
# 16587     det-ing
# 17111     det-ing
# 17700     det-ing
# 18872     det-ing
# 20316     det-ing
# 21969     det-ing
# 22651     det-ing
# 24457     det-ing
# 24467     det-ing
# 27375     det-ing
# 34457     det-ing
# 35587     det-ing
# 35974     det-ing
# 36573     det-ing
# 37667     det-ing
# 38180     det-ing
# 38604     det-ing
# 40623     det-ing
# 40928     det-ing
# 42006     det-ing
# ...
